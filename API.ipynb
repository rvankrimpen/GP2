# %% [markdown]
# # Современные методы анализа данных и машинного обучения, БИ
#
# ## НИУ ВШЭ, 2024-25 учебный год

# %% [markdown]
# ## Групповой проект №2. DE: Scraping & API

# %% [markdown]
# ## Общая информация

# %% [markdown]
# __Дата выдачи:__ 21.02.2025
#
# __Защита проекта:__ 05.03.2025

# %% [markdown]
# ## Формат выполнения

# %% [markdown]
# Групповой проект представляет собой творческое инициативное групповое задание, которое выполняется студентами в командах от 3 до 6 человек. В то же время, следует помнить, что чем больше в команде людей, тем выше предъявляются требования в целом к команде, а также к выполняему ею проекту. Команды разрешается формировать из студентов разных групп.
#
# При оценивании результатов выполнения проекта командой, в обязательном порядке проверяется и учитывается в оценке вклад ***каждого участника*** в общую работу команды. Вследствие этого, крайне важно ответственно подойти к выбору сокомандников, распределению обязанностей внутри команды, а также пресечению наличия "мертвых душ" в команде.
#
# При необходимости, команда большинством голосов имеет право исключить человека из команды *до защиты проекта*, сообщив об этом преподавателю, в случае если такой человек никак не проявлялся в ходе выполнения проекта и являлся как раз таки той самой "мертвой душой". Помните про эту возможность, поскольку наличие "мертвых душ" может негативно повлиять на качество и оценку для всего проекта и, как следствие, в целом для всей команды!
#
# Запись составов команд осуществляется по ссылке в таблице:
#
# https://docs.google.com/spreadsheets/d/1aUFah0NgORUzjMoA6QxKt7OyVN5djf1Vvq3vB1bbx8k/edit?usp=sharing

# %% [markdown]
# ## Оценивание и штрафы

# %% [markdown]
# Групповой проект оценивается исходя из устной защиты (презентации) командой выполненного ими проекта перед комиссией. Комиссия составляется из преподавателей курса, ассистентов курса, а также приглашенных экспертов из индустрии.
#
# В рамках каждой защиты комиссия выставляет два типа оценок.
#
# Первая оценка — это оценка для всего проекта в целом. Она ставится комиссией, исходя из глубины проработки командой предметной области, сложности применяемых в проекте инструментов, а также прочих аспектов, связанных с содержанием выполняемого в проекте ТЗ. При выставлении этой оценки комиссия ориентируется на критерии, более подробно представленные ниже в разделе "Критерии оценки проекта".
#
# Вторая оценка — это индивидуальная оценка каждого участника команды. Именно эта оценка выставляется впоследствии в ведомость. Индивидуальная оценка участника команды определяется комиссией, исходя из того, насколько участник ориентируется в выполненном командой проекте, как он отвечает на адресованные персонально ему вопросы комиссии, насколько в принципе прослеживается его роль в проекте, а также исходя из других аспектов, связанных с участием конкретного человека в деятельности команды. Индивидуальная оценка не может превосходить оценку команды за проект в целом (первую оценку), однако, в случае когда участник спокойно и корректно отвечает на все адресованные ему вопросы, свободно ориентируется в материале и содержании выполненного проекта, а также когда его роль в работе команды не вызывает сомнений, — в таком случае, индивидуальная оценка участника становится равной оценке для всего проекта (т.е. в идеальном случае — вторая оценка равна первой оценке). Кроме того, в исключительных случаях, при демонстрации участником на защите превосходящих ожидания уровней понимания, участия и вовлечения в рамках проекта, комиссия может своим решением повысить индивидуальную оценку для этого участника на 0,5 или 1 балл относительно общей оценки за проект (первой оценки).
#
# Во избежание субъективности и/или предвзятости оценки тех или иных членов комиссии в отношении тех или иных команд, а также каких-либо иных проявлений неравных условий — распределение команд между комиссиями осуществляется абсолютно рандомно с использованием средств библиотеки Numpy :)) — в качестве рэндом сида выступает дата, в которую производится распределение, например, `np.random.seed(21022025)`.
#
# Обратите, пожалуйста, внимание на то, что бОльшая часть комиссий осуществляет приём проектов в очной форме, однако могут присутствовать и 1-2 комиссии, которые будут работать дистанционно с использованием средств видеосвязи. В случае попадания команды путем случайного распределения в комиссию, работающую в очной форме, *не допускается* какое-либо изменение формата проведения для команды на онлайн-режим, равно как и любые другие перемещения команд между комиссиями (смены комиссий), для сохранения честности и непредвзятости случайного распределения.
#
# Явка студента на защиту проекта является обязательной; вклад студента без его присутствия не оценивается и автоматически является равным нулю. Для дистанционных комиссий, дополнительным требованием является обязательное наличие включенной камеры в течение всего времени нахождения в конференции

# %% [markdown]
# ## Описание задания

# %% [markdown]
# В современном мире данных эффективный сбор и интеграция информации из различных источников являются фундаментом для принятия обоснованных решений и успешного ведения бизнеса. Компании, стремясь к конкурентоспособности, активно используют технологии веб-скрапинга и взаимодействия с API для автоматизации процесса сбора данных, обеспечения их актуальности и полноты.
#
# В данном проекте вы на реальных данных попрактикуетесь в том, как осуществляется веб-скрапинг различных сайтов для извлечения необходимой информации, а также в работе с API популярных сервисов для получения структурированных данных. Вы научитесь применять современные инструменты и библиотеки, отражающие различные этапы DE, обрабатывать и очищать полученную информацию, а также интегрировать данные из различных источников для последующего использования их в аналитических и бизнес-задачах.

# %% [markdown]
# ### Постановка задачи

# %% [markdown]
# В рамках этого проекта вы сами найдете датасет, с которым будете работать. Точнее, не найдете, а... соберёте его самостоятельно на основе источников!
#
# Итак, начните с того, что выберите два сайта/портала со схожей тематикой (например, NYT и Bloomberg). Их тематика должна позволять в дальнейшем объединить данные в единую таблицу. Один из этих двух сайтов нужно будет обработать с помощью средств Web-Scraping'a и Data Parsing'a; другой же — используя API.
#
# Определившись с источниками, непосредственно проделайте скачивание данных путём скрейпинга и методами API соответственно и затем объедините всё в финальный датасет. Обязательным требованием к датасету является также наличие в нём как минимум одного столбца с текстовыми данными: описание, состав, комментарии о чём-либо, текст заметки/новости, или что-то ещё.
#
# Кроме того, разумеется, следует помнить, что полученный датасет должен, конечно, быть осмысленным с бизнес-точки зрения и потенциально позволять решать какую-то конкретную бизнес-задачу. Это как минимум означает, что каждому объекту, имеющему своё признаковое пространство — в том числе с текстовым признаком, — должно также соответствовать значение некоторой целевой переменной, которая является релевантной в рамках выбранной вами предметной области.

# %% [markdown]
# Примеры задач, которые мы можем предложить вам в качестве источника для вдохновения — пожалуйста, ни в коем случае не воспринимайте это как исчерпывающий список — это действительно всего лишь примеры:
#
# * Сайт новостей: текстовый столбец — сама новость; признаки — различные характеристики новости: автор, дата публикации, тип новости и т.д.; целевая переменная — количество просмотров новости (можно поделить на число дней с момента даты публикации, чтобы получить «среднее число просмотров в день», что ещё нагляднее)
#
# * Сайт с товарами/книгами/фильмами: текстовый столбец — описание товара/книги/фильма; признаки — различные характеристики объекта: цена, год производства/выпуска, компания-производитель и т.д.; целевая переменная — средний рейтинг объекта
#
# * Блоги: текстовый столбец — тексты заметок; признаки — различные характеристики заметки: автор, время публикации, количество прикрепленных изображений и т.д.; целевая переменная — число просмотров
#
# * И любые другие ваши идеи, которые подходят под описанный выше формат

# %% [markdown]
# После сбора данных и объединения их в общий датасет, необходимо очистить его от мусора (в том числе, например, с помощью регулярных выражений); посчитать различные статистики по собранным данным (в случае если столбец текстовый, то, например, посчитать частотности слов, выявляя наиболее частотные слова, и т.д.); а также в целом провести EDA в контексте той бизнес-задачи, которую мы потенциально хотим решить по полученному датасету. В конце сделать выводы из проделанной работы.

# %% [markdown]
# ### Этапы проекта

# %% [markdown]
# Ниже для вашего удобства еще раз в краткой форме представляем примерные этапы реализации проекта:
#
# - Выбор источников данных, в соответствии с требованиями, описанными выше
# - Формулировка бизнес-задачи, которую могла бы хотеть решить компания/платформа, на основе собираемых данных
# - Обоснование сформулированной бизнес-задачи
# - Извлечение данных путём работы с API
# - Извлечение данных путём скрапинга и парсинга
# - Первичная обработка данных (EDA)
# - Получение и агрегация результатов, финальные выводы

# %% [markdown]
# ### Общие требования к проекту

# %% [markdown]
# В качестве результата выполнения группового проекта ваша команда должна получить презентацию, а также репозиторий с кодом на GitHub. Демонстрация репозитория и защита презентации перед комиссией осуществляется в фиксированную дату.
#
# Оформление презентации остаётся полностью на ваше усмотрение, но помните, что результат должен быть релевантен для демонстрации бизнес-заказчику — комиссию, принимающую вашу работу, правильнее всего воспринимать именно в таком качестве. Например, вставлять в презентацию строчки кода или злоупотреблять скринами блокнота не рекомендуется.
#
# С точки зрения концепции выполнения проекта — вам необходимо принять на себя роль дата-инженеров: продумать идеологию получения и извлечения данных с платформы — и дата-аналитиков: соотнести бизнес-задачу с формулировками на языке данных и извлечь полезные инсайты из проделанной работы. А в конце, конечно, — презентовать всю эту красоту в понятном виде потенциальному заказчику.
#
# Разумеется, чем сложнее и чем нетривиальнее будет ваша задача, а также чем глубже и чем осмысленнее будут выводы, извлечённые в рамках этой задачи, — тем выше окажется качество вашего проекта и тем выше он будет оценён!

# %% [markdown]
# ### Полезные замечания и советы

# %% [markdown]
# - Графики и визуализации — это очень хорошо — все любят графики
# - Следите за тем, чтобы все графики на слайдах можно было прочитать даже без ваших комментариев
# - Не нужно делать просто текстовые слайды
# - Стройте свой проект, исходя из того, что ваша цель представить полезную информацию для бизнеса
# - Любой хороший Data Scientist должен уметь работать в команде, поэтому распределение ваших усилий в проекте остается за вами

# %% [markdown]
# ### Технические требования

# %% [markdown]
# Ниже чуть более детализированно будут представлены минимальные технические требования по всем основным этапам и составным частям выполняемого вами группового проекта.

# %% [markdown]
# #### Обязательный сбор данных через API

# %% [markdown]
# * Необходимо реализовать сбор данных через API для как минимум одного веб-сайта
# * При формировании датасета должно осуществляться **не менее 5** различных запросов к API
# * Данный этап является обязательным, что означает, что без его полного выполнения ***нельзя получить оценку за проект выше 1***

# %% [markdown]
# #### Обязательный сбор данных посредством скрапинга

# %% [markdown]
# * Необходимо реализовать сбор и парсинг данных через библиотеки `requests` / `bs4` и другие рассмотренные в рамках семинара для как минимум одного веб-сайта, отличного от веб-сайта из предыдущего пункта
# * Получившийся датасет должен содержать **не менее 10 000** записей
# * Данный этап является обязательным, что означает, что без его полного выполнения ***нельзя получить оценку за проект выше 1***

# %% [markdown]
# #### Разведочный анализ данных (EDA)

# %% [markdown]
# * Изучить особенности данных в рамках объединённого датасета:
#   * Есть ли пропущенные значения? Сколько? Какова их доля от общего числа объектов для каждого конкретного признака? И, в целом, насколько ваш датасет “разрежен” в контексте пропущенных значений? Выдвинуть и (желательно) проверить гипотезу, что могут означать пропущенные значения? Осмысленно и аргументированно обработать пропуски.
#   * Есть ли ошибочные  (например, отрицательный возраст или пятиметровый рост человека; 3-й класс в задаче бинарной классификации) значения (признаки, целевая переменная) в данных? Обработать их.
#   * Есть ли выбросы в данных? По возможности обработать их.
# * Изучить поведение каждого признака в отдельности, его связь с целевой переменной, а также попарные корреляции (в том числе и в особенности с таргетом). Визуализировать попарные распределения признаков и корреляции наиболее значимых.
# * Построить подходящие сводные таблицы и прочие диаграммы.
# * Если проведенный вами анализ позволяет сделать какие-либо выводы, постараться сформулировать их максимально глубоко и развернуто. Упомянуть, как можно задействовать в дальнейшем приобретенные вами на этом этапе знания в решаемой задаче.
# * Осуществить и другие осмысленные действия в рамках процесса EDA.

# %% [markdown]
# #### GitHub и требования при использовании СКВ

# %% [markdown]
# *   Для выполнения задания вы должны создать проект на GitHub (один репозиторий на всю команду!)
# *   Необходимо добавить в репозиторий `.gitignore` и не грузить в репозиторий лишние файлы
# *   Необходимо добавить в репозиторий `README.md` с подробным описанием проекта. В этот файл также необходимо добавить подробное описание данных — описание признаков, их тип, количество объектов каждого класса (в задачах классификации), информацию о пропущенных значениях (в т.ч о типичных филлерах, если это не `nan`). Также добавляйте другие релевантные вашей задачи описательные характеристики данных. После чтения этого файла у человека со стороны не должно остаться никаких вопросов про данные
# *   В репозитории проекта размещаются ноутбуки / скрипты со сбором данных
# *   Коммиты делаются осмысленно, с понятными внешнему наблюдателю комментариями — что было сделано по факту
# *   При разработке необходимо соблюдать [гитфлоу](https://www.umgum.com/gitlab-workflow)

# %% [markdown]
# #### Артефакты по окончании работы над проектом

# %% [markdown]
# * Ноутбуки / скрипты со сбором и извлечением данных
# * Ноутбуки c осуществлением EDA
# * Файл `.gitignore`
# * Заполненный файл `README.md` в репозитории проекта на гитхабе со ссылкой на данные и их подробным описанием, с выводами о проведенном EDA

# %% [markdown]
# #### Логирование

# %% [markdown]
# * Для получения высоких баллов добавьте в ваш проект логирование. Потренируйтесь включать и выключать его через файл настроек, а также задавать уровень логирования через этот же файл (не в приложении)
# * Запустите ваш код, чтобы сохранился файл с логами
# * Про логи можно почитать [тут](https://habr.com/ru/companies/wunderfund/articles/683880/) и [тут](https://tproger.ru/articles/shpargalka-po-logirovaniju-na-python)

# %% [markdown]
# #### Библиотека Selenium

# %% [markdown]
# * Для получения высоких баллов используйте библиотеку Selenium при сборе данных
# * Реализуйте имитацию работы пользователя через Selenium
# * Про данную библиотеку можно почитать [тут](https://habr.com/ru/companies/selectel/articles/754674/) и [тут](https://happypython.ru/2022/11/27/selenium-chromedriver-find-elements/)

# %% [markdown]
# ## Критерии оценки проекта

# %% [markdown]
# Оценка за групповой проект в целом — то есть первая из двух оценок — выставляется по 10 балльной шкале, исходя из 3 критериев. Также комиссия на своё усмотрение может добавить (но не снизить) некоторое количество бонусных баллов за рамками данных критериев.
#
# Каждый из критериев будет перечислен и рассмотрен ниже.

# %% [markdown]
# ### Критерий 1. Выбор задачи и EDA (до 3,5 баллов)
#
# Данный критерий оценивает, насколько обоснованной и осмысленной получилась решаемая бизнес-задача; насколько полно был осуществлен переход от бизнес-задачи к пайплайну подготовки данных (насколько в реальности формируемый датасет соответствует исходной постановке задачи с точки зрения интересов компании и насколько может помочь в решении такой задачи); а также насколько корректными, объёмными и прикладными для бизнеса получились выявленные в ходе исследования инсайты.

# %% [markdown]
# ### Критерий 2. GitHub (до 1 балла)
#
# Данный критерий оценивает, насколько корректным и квалифицированным было применение средств системы контроля версий в проекте; насколько были выполнены представленные в задании требования по всем необходимым файлам и условиям в рамках работы с GitHub; а также насколько эффективно данная система в действительности использовалась командой для распараллеливания задач по проекту.

# %% [markdown]
# ### Критерий 3. Инструменты извлечения данных (до 5,5 баллов)
#
# Данный критерий оценивает техническую реализацию процесса сбора данных автоматизированным образом с сайтов и порталов. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным.
#
# *__Важно:__ в случае оценки __1 балл и ниже__ за этот критерий — оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить __больше 1 балла__ только при условии применения как средств Data Scraping (автоматического считывания HTML-кода страниц с последующей его обработкой), так и средств API (получению данных с использованием официальных протоколов компании/портала). При этом средства Scraping и API следует применять к разным компаниям/порталам, но представленным в рамках одной и той же предметной области (бизнес-задачи).*
#
# *По данному критерию можно получить **3 балла и выше** только при условии использования в проекте логирования __ИЛИ__ библиотеки Selenium.*
#
# *По данному критерию можно получить **4 балла и выше** только при условии использования в проекте логирования __И__ библиотеки Selenium.*
#
# *По данному критерию можно получить **5 баллов и выше** только при условии использования в проекте логирования, библиотеки Selenium и, кроме этого, обоснованного применения дополнительных инструментов/подходов/библиотек, не упомянутых ранее в этом ноутбуке и не рассматривавшихся в рамках соответствующего семинара.*

# %%
! pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (4.29.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Requirement already satisfied: trio~=0.17 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.2.2)
# Requirement already satisfied: wsproto>=0.14 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
pip install --upgrade webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (4.0.2)
# Requirement already satisfied: requests in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (1.0.1)
# Requirement already satisfied: packaging in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from webdriver-manager) (22.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->webdriver-manager) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install selenium beautifulsoup4
# Out:
# Requirement already satisfied: selenium in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (4.29.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (4.11.1)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Requirement already satisfied: trio~=0.17 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from selenium) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio~=0.17->selenium) (1.2.2)
# Requirement already satisfied: wsproto>=0.14 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jikanpy pandas
# Out:
# Collecting jikanpy
#   Downloading jikanpy-4.3.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (1.5.2)
# Requirement already satisfied: requests in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from jikanpy) (2.32.3)
# Collecting aiohttp (from jikanpy)
#   Downloading aiohttp-3.11.13-cp310-cp310-win_amd64.whl.metadata (8.0 kB)
# Collecting simplejson (from jikanpy)
#   Downloading simplejson-3.20.1-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->jikanpy)
#   Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->jikanpy)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp->jikanpy)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jikanpy) (24.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->jikanpy)
#   Downloading frozenlist-1.5.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->jikanpy)
#   Downloading multidict-6.1.0-cp310-cp310-win_amd64.whl.metadata (5.1 kB)
# Collecting propcache>=0.2.0 (from aiohttp->jikanpy)
#   Downloading propcache-0.3.0-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->jikanpy)
#   Downloading yarl-1.18.3-cp310-cp310-win_amd64.whl.metadata (71 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->jikanpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->jikanpy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->jikanpy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->jikanpy) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from multidict<7.0,>=4.5->aiohttp->jikanpy) (4.12.2)
# Downloading jikanpy-4.3.2-py3-none-any.whl (16 kB)
# Downloading aiohttp-3.11.13-cp310-cp310-win_amd64.whl (442 kB)
# Downloading simplejson-3.20.1-cp310-cp310-win_amd64.whl (75 kB)
# Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading frozenlist-1.5.0-cp310-cp310-win_amd64.whl (51 kB)
# Downloading multidict-6.1.0-cp310-cp310-win_amd64.whl (28 kB)
# Downloading propcache-0.3.0-cp310-cp310-win_amd64.whl (44 kB)
# Downloading yarl-1.18.3-cp310-cp310-win_amd64.whl (90 kB)
# Installing collected packages: simplejson, propcache, multidict, frozenlist, async-timeout, aiohappyeyeballs, yarl, aiosignal, aiohttp, jikanpy
# Successfully installed aiohappyeyeballs-2.4.6 aiohttp-3.11.13 aiosignal-1.3.2 async-timeout-5.0.1 frozenlist-1.5.0 jikanpy-4.3.2 multidict-6.1.0 propcache-0.3.0 simplejson-3.20.1 yarl-1.18.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jikanpy pandas tqdm
# Out:
# Requirement already satisfied: jikanpy in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (4.3.2)
# Requirement already satisfied: pandas in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (1.5.2)
# Requirement already satisfied: tqdm in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (4.67.1)
# Requirement already satisfied: requests in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from jikanpy) (2.32.3)
# Requirement already satisfied: aiohttp in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from jikanpy) (3.11.13)
# Requirement already satisfied: simplejson in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from jikanpy) (3.20.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: colorama in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jikanpy) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jikanpy) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jikanpy) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jikanpy) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jikanpy) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jikanpy) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jikanpy) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from aiohttp->jikanpy) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->jikanpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->jikanpy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->jikanpy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests->jikanpy) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from multidict<7.0,>=4.5->aiohttp->jikanpy) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests pandas openpyxl
# Out:
# Requirement already satisfied: requests in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (2.32.3)
# Requirement already satisfied: pandas in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (1.5.2)
# Requirement already satisfied: openpyxl in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (3.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: et-xmlfile in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\ернур\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import time  # Для добавления задержки между запросами

# Список для хранения всех аниме
anime_list = []

# Количество аниме на одной странице (по ограничению API)
limit = 25  # Максимум 25, согласно документации Jikan API
page = 1

# Пагинация, запрашиваем страницы, пока не получим все аниме
while True:
    url = f"https://api.jikan.moe/v4/top/anime?page={page}&limit={limit}"
    print(f"Запрос на страницу {page}...")

    # Пытаемся выполнить запрос
    try:
        response = requests.get(url)

        # Проверка статуса ответа
        if response.status_code == 200:
            data = response.json()  # Преобразование в JSON формат
            anime_list.extend(data['data'])  # Добавляем данные с текущей страницы в общий список

            print(f"Получено {len(anime_list)} аниме...")

            # Если на текущей странице меньше данных, чем ожидается, значит это последняя страница
            if len(data['data']) < limit:
                print("Достигнут конец данных.")
                break
            page += 1  # Переходим к следующей странице
        else:
            print(f"Ошибка: {response.status_code}, {response.text}")
            break  # Прерываем, если ошибка 400 или 500

        # Задержка между запросами, чтобы избежать превышения лимита
        time.sleep(1)  # Задержка в 1 секунду

    except requests.exceptions.RequestException as e:
        print(f"Ошибка при запросе: {e}")
        break  # Прерываем, если ошибка при подключении или получении данных

# Обрабатываем данные и добавляем жанры, студии, продюсеров и лицензиаров
anime_data = []
for anime in anime_list:
    anime_info = {
        "title": anime['title'],
        "score": anime['score'],
        "type": anime['type'],
        "year": anime['year'],
        "synopsis": anime.get('synopsis', 'Нет описания'),
        # Жанры
        "genres": ', '.join([genre['name'] for genre in anime.get('genres', [])]),
        # Студии
        "studios": ', '.join([studio['name'] for studio in anime.get('studios', [])]),
        # Производители
        "producers": ', '.join([producer['name'] for producer in anime.get('producers', [])]),
        # Лицензиары
        "licensors": ', '.join([licensor['name'] for licensor in anime.get('licensors', [])]),
        # Добавленные новые столбцы
        "source": anime.get('source', 'Не указано'),  # Источник (например, манга, light novel и т.д.)
        "episodes": anime.get('episodes', 'Не указано'),  # Количество серий
        "duration": anime.get('duration', 'Не указано'),  # Продолжительность одной серии
        "rating": anime.get('rating', 'Не указано'),  # Рейтинг (например, PG-13, R и т.д.)
        "scored_by": anime.get('scored_by', 'Не указано'),  # Количество оценивших
        "status": anime.get('status', 'Не указано'),  # Статус (например, выходящий, завершённый и т.д.)
    }
    anime_data.append(anime_info)

# Преобразуем в DataFrame
df = pd.DataFrame(anime_data)

# Выводим информацию о каждом аниме (по желанию)
for anime in df.head(10).iterrows():  # Выводим только первые 10 для примера
    print(f"Название: {anime[1]['title']}")
    print(f"Рейтинг: {anime[1]['score']}")
    print(f"Тип: {anime[1]['type']}")
    print(f"Год выпуска: {anime[1]['year']}")
    print(f"Описание: {anime[1]['synopsis']}")
    print(f"Жанры: {anime[1]['genres']}")
    print(f"Студии: {anime[1]['studios']}")
    print(f"Производители: {anime[1]['producers']}")
    print(f"Лицензиары: {anime[1]['licensors']}")
    print(f"Источник: {anime[1]['source']}")
    print(f"Эпизоды: {anime[1]['episodes']}")
    print(f"Продолжительность: {anime[1]['duration']}")
    print(f"Рейтинг: {anime[1]['rating']}")
    print(f"Оценивших: {anime[1]['scored_by']}")
    print(f"Статус: {anime[1]['status']}")
    print("-" * 50)

# Сохранение в Excel
df.to_excel("all_anime_data_with_more_info_and_new_columns.xlsx", index=False)
print("Все данные успешно сохранены в файл 'all_anime_data_with_more_info_and_new_columns.xlsx'")
# Out:
# Запрос на страницу 1...
# Получено 25 аниме...
# Запрос на страницу 2...
# Получено 50 аниме...
# Запрос на страницу 3...
# Получено 75 аниме...
# Запрос на страницу 4...
# Получено 100 аниме...
# Запрос на страницу 5...
# Получено 125 аниме...
# Запрос на страницу 6...
# Получено 150 аниме...
# Запрос на страницу 7...
# Получено 175 аниме...
# Запрос на страницу 8...
# Получено 200 аниме...
# Запрос на страницу 9...
# Получено 225 аниме...
# Запрос на страницу 10...
# Получено 250 аниме...
# Запрос на страницу 11...
# Получено 275 аниме...
# Запрос на страницу 12...
# Получено 300 аниме...
# Запрос на страницу 13...
# Получено 325 аниме...
# Запрос на страницу 14...
# Получено 350 аниме...
# Запрос на страницу 15...
# Получено 375 аниме...
# Запрос на страницу 16...
# Получено 400 аниме...
# Запрос на страницу 17...
# Получено 425 аниме...
# Запрос на страницу 18...
# Получено 450 аниме...
# Запрос на страницу 19...
# Получено 475 аниме...
# Запрос на страницу 20...
# Получено 500 аниме...
# Запрос на страницу 21...
# Получено 525 аниме...
# Запрос на страницу 22...
# Получено 550 аниме...
# Запрос на страницу 23...
# Получено 575 аниме...
# Запрос на страницу 24...
# Получено 600 аниме...
# Запрос на страницу 25...
# Получено 625 аниме...
# Запрос на страницу 26...
# Получено 650 аниме...
# Запрос на страницу 27...
# Получено 675 аниме...
# Запрос на страницу 28...
# Получено 700 аниме...
# Запрос на страницу 29...
# Получено 725 аниме...
# Запрос на страницу 30...
# Получено 750 аниме...
# Запрос на страницу 31...
# Получено 775 аниме...
# Запрос на страницу 32...
# Получено 800 аниме...
# Запрос на страницу 33...
# Получено 825 аниме...
# Запрос на страницу 34...
# Получено 850 аниме...
# Запрос на страницу 35...
# Получено 875 аниме...
# Запрос на страницу 36...
# Получено 900 аниме...
# Запрос на страницу 37...
# Получено 925 аниме...
# Запрос на страницу 38...
# Получено 950 аниме...
# Запрос на страницу 39...
# Получено 975 аниме...
# Запрос на страницу 40...
# Получено 1000 аниме...
# Запрос на страницу 41...
# Получено 1025 аниме...
# Запрос на страницу 42...
# Получено 1050 аниме...
# Запрос на страницу 43...
# Получено 1075 аниме...
# Запрос на страницу 44...
# Получено 1100 аниме...
# Запрос на страницу 45...
# Получено 1125 аниме...
# Запрос на страницу 46...
# Получено 1150 аниме...
# Запрос на страницу 47...
# Получено 1175 аниме...
# Запрос на страницу 48...
# Получено 1200 аниме...
# Запрос на страницу 49...
# Получено 1225 аниме...
# Запрос на страницу 50...
# Получено 1250 аниме...
# Запрос на страницу 51...
# Получено 1275 аниме...
# Запрос на страницу 52...
# Получено 1300 аниме...
# Запрос на страницу 53...
# Получено 1325 аниме...
# Запрос на страницу 54...
# Получено 1350 аниме...
# Запрос на страницу 55...
# Получено 1375 аниме...
# Запрос на страницу 56...
# Получено 1400 аниме...
# Запрос на страницу 57...
# Получено 1425 аниме...
# Запрос на страницу 58...
# Получено 1450 аниме...
# Запрос на страницу 59...
# Получено 1475 аниме...
# Запрос на страницу 60...
# Получено 1500 аниме...
# Запрос на страницу 61...
# Получено 1525 аниме...
# Запрос на страницу 62...
# Получено 1550 аниме...
# Запрос на страницу 63...
# Получено 1575 аниме...
# Запрос на страницу 64...
# Получено 1600 аниме...
# Запрос на страницу 65...
# Получено 1625 аниме...
# Запрос на страницу 66...
# Получено 1650 аниме...
# Запрос на страницу 67...
# Получено 3125 аниме...
# Запрос на страницу 126...
# Получено 3150 аниме...
# Запрос на страницу 127...
# Получено 3175 аниме...
# Запрос на страницу 128...
# Получено 3200 аниме...
# Запрос на страницу 129...
# Получено 3225 аниме...
# Запрос на страницу 130...
# Получено 3250 аниме...
# Запрос на страницу 131...
# Получено 3275 аниме...
# Запрос на страницу 132...
# Получено 3300 аниме...
# Запрос на страницу 133...
# Получено 3325 аниме...
# Запрос на страницу 134...
# Получено 3350 аниме...
# Запрос на страницу 135...
# Получено 3375 аниме...
# Запрос на страницу 136...
# Получено 3400 аниме...
# Запрос на страницу 137...
# Получено 3425 аниме...
# Запрос на страницу 138...
# Получено 3450 аниме...
# Запрос на страницу 139...
# Получено 3475 аниме...
# Запрос на страницу 140...
# Получено 3500 аниме...
# Запрос на страницу 141...
# Получено 3525 аниме...
# Запрос на страницу 142...
# Получено 3550 аниме...
# Запрос на страницу 143...
# Получено 3575 аниме...
# Запрос на страницу 144...
# Получено 3600 аниме...
# Запрос на страницу 145...
# Получено 3625 аниме...
# Запрос на страницу 146...
# Получено 3650 аниме...
# Запрос на страницу 147...
# Получено 3675 аниме...
# Запрос на страницу 148...
# Получено 3700 аниме...
# Запрос на страницу 149...
# Получено 3725 аниме...
# Запрос на страницу 150...
# Получено 3750 аниме...
# Запрос на страницу 151...
# Получено 3775 аниме...
# Запрос на страницу 152...
# Получено 3800 аниме...
# Запрос на страницу 153...
# Получено 3825 аниме...
# Запрос на страницу 154...
# Получено 3850 аниме...
# Запрос на страницу 155...
# Получено 3875 аниме...
# Запрос на страницу 156...
# Получено 3900 аниме...
# Запрос на страницу 157...
# Получено 3925 аниме...
# Запрос на страницу 158...
# Получено 3950 аниме...
# Запрос на страницу 159...
# Получено 3975 аниме...
# Запрос на страницу 160...
# Получено 4000 аниме...
# Запрос на страницу 161...
# Получено 4025 аниме...
# Запрос на страницу 162...
# Получено 4050 аниме...
# Запрос на страницу 163...
# Получено 4075 аниме...
# Запрос на страницу 164...
# Получено 4100 аниме...
# Запрос на страницу 165...
# Получено 4125 аниме...
# Запрос на страницу 166...
# Получено 4150 аниме...
# Запрос на страницу 167...
# Получено 4175 аниме...
# Запрос на страницу 168...
# Получено 4200 аниме...
# Запрос на страницу 169...
# Получено 4225 аниме...
# Запрос на страницу 170...
# Получено 4250 аниме...
# Запрос на страницу 171...
# Получено 4275 аниме...
# Запрос на страницу 172...
# Получено 4300 аниме...
# Запрос на страницу 173...
# Получено 4325 аниме...
# Запрос на страницу 174...
# Получено 4350 аниме...
# Запрос на страницу 175...
# Получено 4375 аниме...
# Запрос на страницу 176...
# Получено 4400 аниме...
# Запрос на страницу 177...
# Получено 4425 аниме...
# Запрос на страницу 178...
# Получено 4450 аниме...
# Запрос на страницу 179...
# Получено 4475 аниме...
# Запрос на страницу 180...
# Получено 4500 аниме...
# Запрос на страницу 181...
# Получено 4525 аниме...
# Запрос на страницу 182...
# Получено 4550 аниме...
# Запрос на страницу 183...
# Получено 4575 аниме...
# Запрос на страницу 184...
# Получено 4600 аниме...
# Запрос на страницу 185...
# Получено 4625 аниме...
# Запрос на страницу 186...
# Получено 4650 аниме...
# Запрос на страницу 187...
# Получено 4675 аниме...
# Запрос на страницу 188...
# Получено 4700 аниме...
# Запрос на страницу 189...
# Получено 4725 аниме...
# Запрос на страницу 190...
# Получено 4750 аниме...
# Запрос на страницу 191...
# Получено 4775 аниме...
# Запрос на страницу 192...
# Получено 4800 аниме...
# Запрос на страницу 193...
# Получено 4825 аниме...
# Запрос на страницу 194...
# Получено 4850 аниме...
# Запрос на страницу 195...
# Получено 4875 аниме...
# Запрос на страницу 196...
# Получено 4900 аниме...
# Запрос на страницу 197...
# Получено 4925 аниме...
# Запрос на страницу 198...
# Получено 4950 аниме...
# Запрос на страницу 199...
# Получено 4975 аниме...
# Запрос на страницу 200...
# Получено 5000 аниме...
# Запрос на страницу 201...
# Получено 5025 аниме...
# Запрос на страницу 202...
# Получено 5050 аниме...
# Запрос на страницу 203...
# Получено 5075 аниме...
# Запрос на страницу 204...
# Получено 5100 аниме...
# Запрос на страницу 205...
# Получено 5125 аниме...
# Запрос на страницу 206...
# Получено 5150 аниме...
# Запрос на страницу 207...
# Получено 5175 аниме...
# Запрос на страницу 208...
# Получено 5200 аниме...
# Запрос на страницу 209...
# Получено 5225 аниме...
# Запрос на страницу 210...
# Получено 5250 аниме...
# Запрос на страницу 211...
# Получено 5275 аниме...
# Запрос на страницу 212...
# Получено 5300 аниме...
# Запрос на страницу 213...
# Получено 5325 аниме...
# Запрос на страницу 214...
# Получено 5350 аниме...
# Запрос на страницу 215...
# Получено 5375 аниме...
# Запрос на страницу 216...
# Получено 5400 аниме...
# Запрос на страницу 217...
# Получено 5425 аниме...
# Запрос на страницу 218...
# Получено 5450 аниме...
# Запрос на страницу 219...
# Получено 5475 аниме...
# Запрос на страницу 220...
# Получено 5500 аниме...
# Запрос на страницу 221...
# Получено 5525 аниме...
# Запрос на страницу 222...
# Получено 5550 аниме...
# Запрос на страницу 223...
# Получено 5575 аниме...
# Запрос на страницу 224...
# Получено 5600 аниме...
# Запрос на страницу 225...
# Получено 5625 аниме...
# Запрос на страницу 226...
# Получено 5650 аниме...
# Запрос на страницу 227...
# Получено 5675 аниме...
# Запрос на страницу 228...
# Получено 5700 аниме...
# Запрос на страницу 229...
# Получено 5725 аниме...
# Запрос на страницу 230...
# Получено 5750 аниме...
# Запрос на страницу 231...
# Получено 5775 аниме...
# Запрос на страницу 232...
# Получено 5800 аниме...
# Запрос на страницу 233...
# Получено 5825 аниме...
# Запрос на страницу 234...
# Получено 5850 аниме...
# Запрос на страницу 235...
# Получено 5875 аниме...
# Запрос на страницу 236...
# Получено 5900 аниме...
# Запрос на страницу 237...
# Получено 5925 аниме...
# Запрос на страницу 238...
# Получено 5950 аниме...
# Запрос на страницу 239...
# Получено 5975 аниме...
# Запрос на страницу 240...
# Получено 6000 аниме...
# Запрос на страницу 241...
# Получено 6025 аниме...
# Запрос на страницу 242...
# Запрос на страницу 301...
# Получено 7525 аниме...
# Запрос на страницу 302...
# Получено 7550 аниме...
# Запрос на страницу 303...
# Получено 7575 аниме...
# Запрос на страницу 304...
# Получено 7600 аниме...
# Запрос на страницу 305...
# Получено 7625 аниме...
# Запрос на страницу 306...
# Получено 7650 аниме...
# Запрос на страницу 307...
# Получено 7675 аниме...
# Запрос на страницу 308...
# Получено 7700 аниме...
# Запрос на страницу 309...
# Получено 7725 аниме...
# Запрос на страницу 310...
# Получено 7750 аниме...
# Запрос на страницу 311...
# Получено 7775 аниме...
# Запрос на страницу 312...
# Получено 7800 аниме...
# Запрос на страницу 313...
# Получено 7825 аниме...
# Запрос на страницу 314...
# Получено 7850 аниме...
# Запрос на страницу 315...
# Получено 7875 аниме...
# Запрос на страницу 316...
# Получено 7900 аниме...
# Запрос на страницу 317...
# Получено 7925 аниме...
# Запрос на страницу 318...
# Получено 7950 аниме...
# Запрос на страницу 319...
# Получено 7975 аниме...
# Запрос на страницу 320...
# Получено 8000 аниме...
# Запрос на страницу 321...
# Получено 8025 аниме...
# Запрос на страницу 322...
# Получено 8050 аниме...
# Запрос на страницу 323...
# Получено 8075 аниме...
# Запрос на страницу 324...
# Получено 8100 аниме...
# Запрос на страницу 325...
# Получено 8125 аниме...
# Запрос на страницу 326...
# Получено 8150 аниме...
# Запрос на страницу 327...
# Получено 8175 аниме...
# Запрос на страницу 328...
# Получено 8200 аниме...
# Запрос на страницу 329...
# Получено 8225 аниме...
# Запрос на страницу 330...
# Получено 8250 аниме...
# Запрос на страницу 331...
# Получено 8275 аниме...
# Запрос на страницу 332...
# Получено 8300 аниме...
# Запрос на страницу 333...
# Получено 8325 аниме...
# Запрос на страницу 334...
# Получено 8350 аниме...
# Запрос на страницу 335...
# Получено 8375 аниме...
# Запрос на страницу 336...
# Получено 8400 аниме...
# Запрос на страницу 337...
# Получено 8425 аниме...
# Запрос на страницу 338...
# Получено 8450 аниме...
# Запрос на страницу 339...
# Получено 8475 аниме...
# Запрос на страницу 340...
# Получено 8500 аниме...
# Запрос на страницу 341...
# Получено 8525 аниме...
# Запрос на страницу 342...
# Получено 8550 аниме...
# Запрос на страницу 343...
# Получено 8575 аниме...
# Запрос на страницу 344...
# Получено 8600 аниме...
# Запрос на страницу 345...
# Получено 8625 аниме...
# Запрос на страницу 346...
# Получено 8650 аниме...
# Запрос на страницу 347...
# Получено 8675 аниме...
# Запрос на страницу 348...
# Получено 8700 аниме...
# Запрос на страницу 349...
# Получено 8725 аниме...
# Запрос на страницу 350...
# Получено 8750 аниме...
# Запрос на страницу 351...
# Получено 8775 аниме...
# Запрос на страницу 352...
# Получено 8800 аниме...
# Запрос на страницу 353...
# Получено 8825 аниме...
# Запрос на страницу 354...
# Получено 8850 аниме...
# Запрос на страницу 355...
# Получено 8875 аниме...
# Запрос на страницу 356...
# Получено 8900 аниме...
# Запрос на страницу 357...
# Получено 8925 аниме...
# Запрос на страницу 358...
# Получено 8950 аниме...
# Получено 13350 аниме...
# Запрос на страницу 535...
# Получено 13375 аниме...
# Запрос на страницу 536...
# Получено 13400 аниме...
# Запрос на страницу 537...
# Получено 13425 аниме...
# Запрос на страницу 538...
# Получено 13450 аниме...
# Запрос на страницу 539...
# Получено 13475 аниме...
# Запрос на страницу 540...
# Получено 13500 аниме...
# Запрос на страницу 541...
# Получено 13525 аниме...
# Запрос на страницу 542...
# Получено 13550 аниме...
# Запрос на страницу 543...
# Получено 13575 аниме...
# Запрос на страницу 544...
# Получено 13600 аниме...
# Запрос на страницу 545...
# Получено 13625 аниме...
# Запрос на страницу 546...
# Получено 13650 аниме...
# Запрос на страницу 547...
# Получено 13675 аниме...
# Запрос на страницу 548...
# Получено 13700 аниме...
# Запрос на страницу 549...
# Получено 13725 аниме...
# Запрос на страницу 550...
# Получено 13750 аниме...
# Запрос на страницу 551...
# Получено 13775 аниме...
# Запрос на страницу 552...
# Получено 13800 аниме...
# Запрос на страницу 553...
# Получено 13825 аниме...
# Запрос на страницу 554...
# Получено 13850 аниме...
# Запрос на страницу 555...
# Получено 13875 аниме...
# Запрос на страницу 556...
# Получено 13900 аниме...
# Запрос на страницу 557...
# Получено 13925 аниме...
# Запрос на страницу 558...
# Получено 13950 аниме...
# Запрос на страницу 559...
# Получено 13975 аниме...
# Запрос на страницу 560...
# Получено 14000 аниме...
# Запрос на страницу 561...
# Получено 14025 аниме...
# Запрос на страницу 562...
# Получено 14050 аниме...
# Запрос на страницу 563...
# Получено 14075 аниме...
# Запрос на страницу 564...
# Получено 14100 аниме...
# Запрос на страницу 565...
# Получено 14125 аниме...
# Запрос на страницу 566...
# Получено 14150 аниме...
# Запрос на страницу 567...
# Получено 14175 аниме...
# Запрос на страницу 568...
# Получено 14200 аниме...
# Запрос на страницу 569...
# Получено 14225 аниме...
# Запрос на страницу 570...
# Получено 14250 аниме...
# Запрос на страницу 571...
# Получено 14275 аниме...
# Запрос на страницу 572...
# Получено 14300 аниме...
# Запрос на страницу 573...
# Получено 14325 аниме...
# Запрос на страницу 574...
# Получено 14350 аниме...
# Запрос на страницу 575...
# Получено 14375 аниме...
# Запрос на страницу 576...
# Получено 14400 аниме...
# Запрос на страницу 577...
# Получено 14425 аниме...
# Запрос на страницу 578...
# Получено 14450 аниме...
# Запрос на страницу 579...
# Получено 14475 аниме...
# Запрос на страницу 580...
# Получено 14500 аниме...
# Запрос на страницу 581...
# Получено 14525 аниме...
# Запрос на страницу 582...
# Получено 14550 аниме...
# Запрос на страницу 583...
# Получено 14575 аниме...
# Запрос на страницу 584...
# Получено 14600 аниме...
# Запрос на страницу 585...
# Получено 14625 аниме...
# Запрос на страницу 586...
# Получено 14650 аниме...
# Запрос на страницу 587...
# Получено 14675 аниме...
# Запрос на страницу 588...
# Получено 14700 аниме...
# Запрос на страницу 589...
# Получено 14725 аниме...
# Запрос на страницу 590...
# Получено 14750 аниме...
# Запрос на страницу 591...
# Получено 14775 аниме...
# Запрос на страницу 592...
# Получено 14800 аниме...
# Запрос на страницу 593...
# Получено 14825 аниме...
# Запрос на страницу 594...
# Получено 14850 аниме...
# Запрос на страницу 595...
# Получено 14875 аниме...
# Запрос на страницу 596...
# Получено 14900 аниме...
# Запрос на страницу 597...
# Получено 14925 аниме...
# Запрос на страницу 598...
# Получено 14950 аниме...
# Запрос на страницу 599...
# Получено 14975 аниме...
# Запрос на страницу 600...
# Получено 15000 аниме...
# Запрос на страницу 601...
# Получено 15025 аниме...
# Запрос на страницу 602...
# Получено 15050 аниме...
# Запрос на страницу 603...
# Получено 15075 аниме...
# Запрос на страницу 604...
# Получено 15100 аниме...
# Запрос на страницу 605...
# Получено 15125 аниме...
# Запрос на страницу 606...
# Получено 15150 аниме...
# Запрос на страницу 607...
# Получено 15175 аниме...
# Запрос на страницу 608...
# Получено 15200 аниме...
# Запрос на страницу 609...
# Получено 15225 аниме...
# Запрос на страницу 610...
# Получено 15250 аниме...
# Запрос на страницу 611...
# Получено 15275 аниме...
# Запрос на страницу 612...
# Получено 15300 аниме...
# Запрос на страницу 613...
# Получено 15325 аниме...
# Запрос на страницу 614...
# Получено 15350 аниме...
# Запрос на страницу 615...
# Получено 15375 аниме...
# Запрос на страницу 616...
# Получено 15400 аниме...
# Запрос на страницу 617...
# Получено 15425 аниме...
# Запрос на страницу 618...
# Получено 15450 аниме...
# Запрос на страницу 619...
# Получено 15475 аниме...
# Запрос на страницу 620...
# Получено 15500 аниме...
# Запрос на страницу 621...
# Получено 15525 аниме...
# Запрос на страницу 622...
# Получено 15550 аниме...
# Запрос на страницу 623...
# Получено 15575 аниме...
# Запрос на страницу 624...
# Получено 15600 аниме...
# Запрос на страницу 625...
# Получено 15625 аниме...
# Запрос на страницу 626...
# Получено 15650 аниме...
# Запрос на страницу 627...
# Получено 15675 аниме...
# Запрос на страницу 628...
# Получено 15700 аниме...
# Запрос на страницу 629...
# Получено 15725 аниме...
# Запрос на страницу 630...
# Получено 15750 аниме...
# Запрос на страницу 631...
# Получено 15775 аниме...
# Запрос на страницу 632...
# Получено 15800 аниме...
# Запрос на страницу 633...
# Получено 15825 аниме...
# Запрос на страницу 634...
# Получено 15850 аниме...
# Запрос на страницу 635...
# Получено 15875 аниме...
# Запрос на страницу 636...
# Получено 15900 аниме...
# Запрос на страницу 637...
# Получено 15925 аниме...
# Запрос на страницу 638...
# Получено 15950 аниме...
# Запрос на страницу 639...
# Получено 15975 аниме...
# Запрос на страницу 640...
# Получено 16000 аниме...
# Запрос на страницу 641...
# Получено 16025 аниме...
# Запрос на страницу 642...
# Получено 16050 аниме...
# Запрос на страницу 643...
# Получено 16075 аниме...
# Запрос на страницу 644...
# Получено 16100 аниме...
# Запрос на страницу 645...
# Получено 16125 аниме...
# Запрос на страницу 646...
# Получено 16150 аниме...
# Запрос на страницу 647...
# Получено 16175 аниме...
# Запрос на страницу 648...
# Получено 16200 аниме...
# Запрос на страницу 649...
# Получено 16225 аниме...
# Запрос на страницу 650...
# Получено 16250 аниме...
# Запрос на страницу 651...
# Получено 16275 аниме...
# Запрос на страницу 652...
# Получено 16300 аниме...
# Запрос на страницу 653...
# Получено 16325 аниме...
# Запрос на страницу 654...
# Получено 16350 аниме...
# Запрос на страницу 655...
# Получено 16375 аниме...
# Запрос на страницу 656...
# Получено 16400 аниме...
# Запрос на страницу 657...
# Получено 16425 аниме...
# Запрос на страницу 658...
# Получено 16450 аниме...
# Запрос на страницу 659...
# Получено 16475 аниме...
# Запрос на страницу 660...
# Получено 16500 аниме...
# Запрос на страницу 661...
# Получено 16525 аниме...
# Запрос на страницу 662...
# Получено 16550 аниме...
# Запрос на страницу 663...
# Получено 16575 аниме...
# Запрос на страницу 664...
# Получено 16600 аниме...
# Запрос на страницу 665...
# Получено 16625 аниме...
# Запрос на страницу 666...
# Получено 16650 аниме...
# Запрос на страницу 667...
# Получено 16675 аниме...
# Запрос на страницу 668...
# Получено 16700 аниме...
# Запрос на страницу 669...
# Получено 16725 аниме...
# Запрос на страницу 670...
# Получено 16750 аниме...
# Запрос на страницу 671...
# Получено 16775 аниме...
# Запрос на страницу 672...
# Получено 16800 аниме...
# Запрос на страницу 673...
# Получено 16825 аниме...
# Запрос на страницу 674...
# Получено 16850 аниме...
# Запрос на страницу 675...
# Получено 16875 аниме...
# Запрос на страницу 676...
# Получено 16900 аниме...
# Запрос на страницу 677...
# Получено 16925 аниме...
# Запрос на страницу 678...
# Получено 16950 аниме...
# Запрос на страницу 679...
# Получено 16975 аниме...
# Запрос на страницу 680...
# Получено 17000 аниме...
# Запрос на страницу 681...
# Получено 17025 аниме...
# Запрос на страницу 682...
# Получено 17050 аниме...
# Запрос на страницу 683...
# Получено 17075 аниме...
# Запрос на страницу 684...
# Получено 17100 аниме...
# Запрос на страницу 685...
# Получено 17125 аниме...
# Запрос на страницу 686...
# Получено 17150 аниме...
# Запрос на страницу 687...
# Получено 17175 аниме...
# Запрос на страницу 688...
# Получено 17200 аниме...
# Запрос на страницу 689...
# Получено 17225 аниме...
# Запрос на страницу 690...
# Получено 17250 аниме...
# Запрос на страницу 691...
# Получено 17275 аниме...
# Запрос на страницу 692...
# Получено 17300 аниме...
# Запрос на страницу 693...
# Получено 17325 аниме...
# Запрос на страницу 694...
# Получено 17350 аниме...
# Запрос на страницу 695...
# Получено 17375 аниме...
# Запрос на страницу 696...
# Получено 17400 аниме...
# Запрос на страницу 697...
# Получено 17425 аниме...
# Запрос на страницу 698...
# Получено 17450 аниме...
# Запрос на страницу 699...
# Получено 17475 аниме...
# Запрос на страницу 700...
# Получено 17500 аниме...
# Запрос на страницу 701...
# Получено 17525 аниме...
# Запрос на страницу 702...
# Получено 17550 аниме...
# Запрос на страницу 703...
# Получено 17575 аниме...
# Запрос на страницу 704...
# Получено 17600 аниме...
# Запрос на страницу 705...
# Получено 17625 аниме...
# Запрос на страницу 706...
# Получено 17650 аниме...
# Запрос на страницу 707...
# Получено 17675 аниме...
# Запрос на страницу 708...
# Получено 17700 аниме...
# Запрос на страницу 709...
# Получено 17725 аниме...
# Запрос на страницу 710...
# Получено 17750 аниме...
# Запрос на страницу 711...
# Получено 17775 аниме...
# Запрос на страницу 712...
# Получено 17800 аниме...
# Запрос на страницу 713...
# Получено 17825 аниме...
# Запрос на страницу 714...
# Получено 17850 аниме...
# Запрос на страницу 715...
# Получено 17875 аниме...
# Запрос на страницу 716...
# Получено 17900 аниме...
# Запрос на страницу 717...
# Получено 17925 аниме...
# Запрос на страницу 718...
# Получено 17950 аниме...
# Запрос на страницу 719...
# Получено 17975 аниме...
# Запрос на страницу 720...
# Получено 18000 аниме...
# Запрос на страницу 721...
# Получено 18025 аниме...
# Запрос на страницу 722...
# Получено 18050 аниме...
# Запрос на страницу 723...
# Получено 18075 аниме...
# Запрос на страницу 724...
# Получено 18100 аниме...
# Запрос на страницу 725...
# Получено 18125 аниме...
# Запрос на страницу 726...
# Получено 18150 аниме...
# Запрос на страницу 727...
# Получено 18175 аниме...
# Запрос на страницу 728...
# Получено 18200 аниме...
# Запрос на страницу 729...
# Получено 18225 аниме...
# Запрос на страницу 730...
# Получено 18250 аниме...
# Запрос на страницу 731...
# Получено 18275 аниме...
# Запрос на страницу 732...
# Получено 18300 аниме...
# Запрос на страницу 733...
# Получено 18325 аниме...
# Запрос на страницу 734...
# Получено 18350 аниме...
# Запрос на страницу 735...
# Получено 18375 аниме...
# Запрос на страницу 736...
# Получено 18400 аниме...
# Запрос на страницу 737...
# Получено 18425 аниме...
# Запрос на страницу 738...
# Получено 18450 аниме...
# Запрос на страницу 739...
# Получено 18475 аниме...
# Запрос на страницу 740...
# Получено 18500 аниме...
# Запрос на страницу 741...
# Получено 18525 аниме...
# Запрос на страницу 742...
# Получено 18550 аниме...
# Запрос на страницу 743...
# Получено 18575 аниме...
# Запрос на страницу 744...
# Получено 18600 аниме...
# Запрос на страницу 745...
# Получено 18625 аниме...
# Запрос на страницу 746...
# Получено 18650 аниме...
# Запрос на страницу 747...
# Получено 18675 аниме...
# Запрос на страницу 748...
# Получено 18700 аниме...
# Запрос на страницу 749...
# Получено 18725 аниме...
# Запрос на страницу 750...
# Получено 18750 аниме...
# Запрос на страницу 751...
# Получено 18775 аниме...
# Запрос на страницу 752...
# Получено 18800 аниме...
# Запрос на страницу 753...
# Получено 18825 аниме...
# Запрос на страницу 754...
# Получено 18850 аниме...
# Запрос на страницу 755...
# Получено 18875 аниме...
# Запрос на страницу 756...
# Получено 18900 аниме...
# Запрос на страницу 757...
# Получено 18925 аниме...
# Запрос на страницу 758...
# Получено 18950 аниме...
# Запрос на страницу 759...
# Получено 18975 аниме...
# Запрос на страницу 760...
# Получено 19000 аниме...
# Запрос на страницу 761...
# Получено 19025 аниме...
# Запрос на страницу 762...
# Получено 19050 аниме...
# Запрос на страницу 763...
# Получено 19075 аниме...
# Запрос на страницу 764...
# Получено 19100 аниме...
# Запрос на страницу 765...
# Получено 19125 аниме...
# Запрос на страницу 766...
# Получено 19150 аниме...
# Запрос на страницу 767...
# Получено 19175 аниме...
# Запрос на страницу 1150...
# Получено 28742 аниме...
# Достигнут конец данных.
# Название: Sousou no Frieren
# Рейтинг: 9.31
# Тип: TV
# Год выпуска: 2023.0
# Описание: During their decade-long quest to defeat the Demon King, the members of the hero's party—Himmel himself, the priest Heiter, the dwarf warrior Eisen, and the elven mage Frieren—forge bonds through adventures and battles, creating unforgettable precious memories for most of them.
#
# However, the time that Frieren spends with her comrades is equivalent to merely a fraction of her life, which has lasted over a thousand years. When the party disbands after their victory, Frieren casually returns to her "usual" routine of collecting spells across the continent. Due to her different sense of time, she seemingly holds no strong feelings toward the experiences she went through.
#
# As the years pass, Frieren gradually realizes how her days in the hero's party truly impacted her. Witnessing the deaths of two of her former companions, Frieren begins to regret having taken their presence for granted; she vows to better understand humans and create real personal connections. Although the story of that once memorable journey has long ended, a new tale is about to begin.
#
# [Written by MAL Rewrite]
# Жанры: Adventure, Drama, Fantasy
# Студии: Madhouse
# Производители: Aniplex, Dentsu, Shogakukan-Shueisha Productions, Nippon Television Network, TOHO animation, Shogakukan
# Лицензиары: Crunchyroll
# Источник: Manga
# Эпизоды: 28.0
# Продолжительность: 24 min per ep
# Рейтинг: PG-13 - Teens 13 or older
# Оценивших: 605478.0
# Статус: Finished Airing
# --------------------------------------------------
# Название: Fullmetal Alchemist: Brotherhood
# Рейтинг: 9.1
# Тип: TV
# Год выпуска: 2009.0
# Описание: After a horrific alchemy experiment goes wrong in the Elric household, brothers Edward and Alphonse are left in a catastrophic new reality. Ignoring the alchemical principle banning human transmutation, the boys attempted to bring their recently deceased mother back to life. Instead, they suffered brutal personal loss: Alphonse's body disintegrated while Edward lost a leg and then sacrificed an arm to keep Alphonse's soul in the physical realm by binding it to a hulking suit of armor.
#
# The brothers are rescued by their neighbor Pinako Rockbell and her granddaughter Winry. Known as a bio-mechanical engineering prodigy, Winry creates prosthetic limbs for Edward by utilizing "automail," a tough, versatile metal used in robots and combat armor. After years of training, the Elric brothers set off on a quest to restore their bodies by locating the Philosopher's Stone—a powerful gem that allows an alchemist to defy the traditional laws of Equivalent Exchange.
#
# As Edward becomes an infamous alchemist and gains the nickname "Fullmetal," the boys' journey embroils them in a growing conspiracy that threatens the fate of the world.
#
# [Written by MAL Rewrite]
# Жанры: Action, Adventure, Drama, Fantasy
# Студии: Bones
# Производители: Aniplex, Square Enix, Mainichi Broadcasting System, Techno Sound
# Лицензиары: Funimation, Aniplex of America
# Источник: Manga
# Эпизоды: 64.0
# Продолжительность: 24 min per ep
# Рейтинг: R - 17+ (violence & profanity)
# Оценивших: 2196965.0
# Статус: Finished Airing
# --------------------------------------------------
# Название: Steins;Gate
# Рейтинг: 9.07
# Тип: TV
# Год выпуска: 2011.0
# Описание: Eccentric scientist Rintarou Okabe has a never-ending thirst for scientific exploration. Together with his ditzy but well-meaning friend Mayuri Shiina and his roommate Itaru Hashida, Okabe founds the Future Gadget Laboratory in the hopes of creating technological innovations that baffle the human psyche. Despite claims of grandeur, the only notable "gadget" the trio have created is a microwave that has the mystifying power to turn bananas into green goo.
#
# However, when Okabe attends a conference on time travel, he experiences a series of strange events that lead him to believe that there is more to the "Phone Microwave" gadget than meets the eye. Apparently able to send text messages into the past using the microwave, Okabe dabbles further with the "time machine," attracting the ire and attention of the mysterious organization SERN.
#
# Due to the novel discovery, Okabe and his friends find themselves in an ever-present danger. As he works to mitigate the damage his invention has caused to the timeline, Okabe fights a battle to not only save his loved ones but also to preserve his degrading sanity.
#
# [Written by MAL Rewrite]
# Жанры: Drama, Sci-Fi, Suspense
# Студии: White Fox
# Производители: Frontier Works, Media Factory, Kadokawa Shoten, Movic, AT-X, Kadokawa Pictures Japan, Nitroplus
# Лицензиары: Funimation
# Источник: Visual novel
# Эпизоды: 24.0
# Продолжительность: 24 min per ep
# Рейтинг: PG-13 - Teens 13 or older
# Оценивших: 1450343.0
# Статус: Finished Airing
# --------------------------------------------------
# Название: One Piece Fan Letter
# Рейтинг: 9.06
# Тип: TV Special
# Год выпуска: nan
# Описание: Although the golden age of piracy is about to reach new heights, most people do not seek the glory of finding the elusive One Piece—a treasure signifying a new conqueror of all seas that was once embodied by the legendary King of the Pirates, Gol D. Roger. However, even if civilians generally despise pirates, they secretly cheer for at least one of them.
#
# One red-headed girl from Sabaody Archipelago is no exception: She reveres Nami, the ingenious female navigator of Monkey D. Luffy's Straw Hat crew. Determined to deliver a fan letter to her idol, the Sabaody child is prepared to challenge forces of authority who strive to prevent Luffy and his friends from departing for their next destination: the New World. But to succeed, Nami's fan may need to risk her life and interfere with the Marines' plans, potentially causing devastating consequences for the wider world.
#
# [Written by MAL Rewrite]
# Жанры: Action, Adventure, Fantasy
# Студии: Toei Animation
# Производители:
# Лицензиары:
# Источник: Light novel
# Эпизоды: 1.0
# Продолжительность: 24 min
# Рейтинг: PG-13 - Teens 13 or older
# Оценивших: 69428.0
# Статус: Finished Airing
# --------------------------------------------------
# Название: Shingeki no Kyojin Season 3 Part 2
# Рейтинг: 9.05
# Тип: TV
# Год выпуска: 2019.0
# Описание: Seeking to restore humanity's diminishing hope, the Survey Corps embark on a mission to retake Wall Maria, where the battle against the merciless "Titans" takes the stage once again.
#
# Returning to the tattered Shiganshina District that was once his home, Eren Yeager and the Corps find the town oddly unoccupied by Titans. Even after the outer gate is plugged, they strangely encounter no opposition. The mission progresses smoothly until Armin Arlert, highly suspicious of the enemy's absence, discovers distressing signs of a potential scheme against them.
#
# Shingeki no Kyojin Season 3 Part 2 follows Eren as he vows to take back everything that was once his. Alongside him, the Survey Corps strive—through countless sacrifices—to carve a path towards victory and uncover the secrets locked away in the Yeager family's basement.
#
# [Written by MAL Rewrite]
# Жанры: Action, Drama, Suspense
# Студии: Wit Studio
# Производители: Production I.G, Dentsu, Mainichi Broadcasting System, Pony Canyon, Kodansha, Techno Sound, Pony Canyon Enterprises
# Лицензиары: Funimation
# Источник: Manga
# Эпизоды: 10.0
# Продолжительность: 23 min per ep
# Рейтинг: R - 17+ (violence & profanity)
# Оценивших: 1671699.0
# Статус: Finished Airing
# --------------------------------------------------
# Название: Gintama°
# Рейтинг: 9.05
# Тип: TV
# Год выпуска: 2015.0
# Описание: Gintoki, Shinpachi, and Kagura return as the fun-loving but broke members of the Yorozuya team! Living in an alternate-reality Edo, where swords are prohibited and alien overlords have conquered Japan, they try to thrive on doing whatever work they can get their hands on. However, Shinpachi and Kagura still haven't been paid... Does Gin-chan really spend all that cash playing pachinko?
#
# Meanwhile, when Gintoki drunkenly staggers home one night, an alien spaceship crashes nearby. A fatally injured crew member emerges from the ship and gives Gintoki a strange, clock-shaped device, warning him that it is incredibly powerful and must be safeguarded. Mistaking it for his alarm clock, Gintoki proceeds to smash the device the next morning and suddenly discovers that the world outside his apartment has come to a standstill. With Kagura and Shinpachi at his side, he sets off to get the device fixed; though, as usual, nothing is ever that simple for the Yorozuya team.
#
# Filled with tongue-in-cheek humor and moments of heartfelt emotion, Gintama's fourth season finds Gintoki and his friends facing both their most hilarious misadventures and most dangerous crises yet.
#
# [Written by MAL Rewrite]
# Жанры: Action, Comedy, Sci-Fi
# Студии: Bandai Namco Pictures
# Производители: TV Tokyo, Aniplex, Dentsu
# Лицензиары: Funimation, Crunchyroll
# Источник: Manga
# Эпизоды: 51.0
# Продолжительность: 24 min per ep
# Рейтинг: PG-13 - Teens 13 or older
# Оценивших: 260544.0
# Статус: Finished Airing
# --------------------------------------------------
# Название: Gintama: The Final
# Рейтинг: 9.04
# Тип: Movie
# Год выпуска: nan
# Описание: Two years have passed following the Tendoshuu's invasion of the O-Edo Central Terminal. Since then, the Yorozuya have gone their separate ways. Foreseeing Utsuro's return, Gintoki Sakata begins surveying Earth's ley lines for traces of the other man's Altana. After an encounter with the remnants of the Tendoshuu—who continue to press on in search of immortality—Gintoki returns to Edo.
#
# Later, the regrouped Shinsengumi and Yorozuya begin an attack on the occupied Central Terminal. With the Altana harvested by the wreckage of the Tendoshuu's ship in danger of detonating, the Yorozuya and their allies fight their enemies while the safety of Edo—and the rest of the world—hangs in the balance. Fulfilling the wishes of their teacher, Shouyou Yoshida's former students unite and relive their pasts one final time in an attempt to save their futures.
#
# [Written by MAL Rewrite]
# Жанры: Action, Comedy, Drama, Sci-Fi
# Студии: Bandai Namco Pictures
# Производители: TV Tokyo, Aniplex, Dentsu, Bandai, Warner Bros. Japan, Shueisha
# Лицензиары: Eleven Arts
# Источник: Manga
# Эпизоды: 1.0
# Продолжительность: 1 hr 44 min
# Рейтинг: PG-13 - Teens 13 or older
# Оценивших: 78097.0
# Статус: Finished Airing
# --------------------------------------------------
# Название: Hunter x Hunter (2011)
# Рейтинг: 9.03
# Тип: TV
# Год выпуска: 2011.0
# Описание: Hunters devote themselves to accomplishing hazardous tasks, all from traversing the world's uncharted territories to locating rare items and monsters. Before becoming a Hunter, one must pass the Hunter Examination—a high-risk selection process in which most applicants end up handicapped or worse, deceased.
#
# Ambitious participants who challenge the notorious exam carry their own reason. What drives 12-year-old Gon Freecss is finding Ging, his father and a Hunter himself. Believing that he will meet his father by becoming a Hunter, Gon takes the first step to walk the same path.
#
# During the Hunter Examination, Gon befriends the medical student Leorio Paladiknight, the vindictive Kurapika, and ex-assassin Killua Zoldyck. While their motives vastly differ from each other, they band together for a common goal and begin to venture into a perilous world.
#
# [Written by MAL Rewrite]
# Жанры: Action, Adventure, Fantasy
# Студии: Madhouse
# Производители: VAP, Nippon Television Network, Shueisha
# Лицензиары: VIZ Media
# Источник: Manga
# Эпизоды: 148.0
# Продолжительность: 23 min per ep
# Рейтинг: PG-13 - Teens 13 or older
# Оценивших: 1852897.0
# Статус: Finished Airing
# --------------------------------------------------
# Название: Gintama'
# Рейтинг: 9.02
# Тип: TV
# Год выпуска: 2011.0
# Описание: After a one-year hiatus, Shinpachi Shimura returns to Edo, only to stumble upon a shocking surprise: Gintoki and Kagura, his fellow Yorozuya members, have become completely different characters! Fleeing from the Yorozuya headquarters in confusion, Shinpachi finds that all the denizens of Edo have undergone impossibly extreme changes, in both appearance and personality. Most unbelievably, his sister Otae has married the Shinsengumi chief and shameless stalker Isao Kondou and is pregnant with their first child.
#
# Bewildered, Shinpachi agrees to join the Shinsengumi at Otae and Kondou's request and finds even more startling transformations afoot both in and out of the ranks of the the organization. However, discovering that Vice Chief Toushirou Hijikata has remained unchanged, Shinpachi and his unlikely Shinsengumi ally set out to return the city of Edo to how they remember it.
#
# With even more dirty jokes, tongue-in-cheek parodies, and shameless references, Gintama' follows the Yorozuya team through more of their misadventures in the vibrant, alien-filled world of Edo.
#
# [Written by MAL Rewrite]
# Жанры: Action, Comedy, Sci-Fi
# Студии: Sunrise
# Производители: TV Tokyo, Aniplex, Dentsu, Trinity Sound, Miracle Robo, Shueisha
# Лицензиары:
# Источник: Manga
# Эпизоды: 51.0
# Продолжительность: 24 min per ep
# Рейтинг: PG-13 - Teens 13 or older
# Оценивших: 245932.0
# Статус: Finished Airing
# --------------------------------------------------
# Название: Gintama': Enchousen
# Рейтинг: 9.02
# Тип: TV
# Год выпуска: 2012.0
# Описание: While Gintoki Sakata was away, the Yorozuya found themselves a new leader: Kintoki, Gintoki's golden-haired doppelganger. In order to regain his former position, Gintoki will need the help of those around him, a troubling feat when no one can remember him! Between Kintoki and Gintoki, who will claim the throne as the main character?
#
# In addition, Yorozuya make a trip back down to red-light district of Yoshiwara to aid an elderly courtesan in her search for her long-lost lover. Although the district is no longer in chains beneath the earth's surface, the trio soon learn of the tragic backstories of Yoshiwara's inhabitants that still haunt them. With flashback after flashback, this quest has Yorozuya witnessing everlasting love and protecting it as best they can with their hearts and souls.
#
# [Written by MAL Rewrite]
# Жанры: Action, Comedy, Sci-Fi
# Студии: Sunrise
# Производители: TV Tokyo, Aniplex, Dentsu, Shueisha, Miracle Bus
# Лицензиары:
# Источник: Manga
# Эпизоды: 13.0
# Продолжительность: 24 min per ep
# Рейтинг: PG-13 - Teens 13 or older
# Оценивших: 171265.0
# Статус: Finished Airing
# --------------------------------------------------
# Все данные успешно сохранены в файл 'all_anime_data_with_more_info_and_new_columns.xlsx'
